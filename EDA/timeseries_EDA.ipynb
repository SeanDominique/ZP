# %%
# !ls
# Out:
# test.ipynb           timeseries_EDA.ipynb

# %% [markdown]
# # Goal: Study the HRV of each member and how it is affected by different features in the data.
# ### Is there anything about their general fitness or behaviour that will affect their HRV levels?

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Import python packages

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
import os
from tqdm import tqdm

# %%
file_names1 = os.listdir("../data2/fitbit_EDA/Fitabase Data 3.12.16-4.11.16")
file_names2 = os.listdir("../data2/fitbit_EDA/Fitabase Data 4.12.16-5.12.16")

file_names1, file_names2
# Out:
# (['dailyActivity_merged.csv',
#   'heartrate_seconds_merged.csv',
#   'minuteIntensitiesNarrow_merged.csv',
#   'minuteMETsNarrow_merged.csv',
#   'hourlySteps_merged.csv',
#   'hourlyIntensities_merged.csv',
#   'hourlyCalories_merged.csv',
#   'minuteSleep_merged.csv',
#   'minuteCaloriesNarrow_merged.csv',
#   'minuteStepsNarrow_merged.csv',
#   'weightLogInfo_merged.csv'],
#  ['minuteIntensitiesWide_merged.csv',
#   'dailyActivity_merged.csv',
#   'sleepDay_merged.csv',
#   'heartrate_seconds_merged.csv',
#   'minuteIntensitiesNarrow_merged.csv',
#   'minuteMETsNarrow_merged.csv',
#   'hourlySteps_merged.csv',
#   'hourlyIntensities_merged.csv',
#   'dailyCalories_merged.csv',
#   'hourlyCalories_merged.csv',
#   'minuteSleep_merged.csv',
#   'minuteCaloriesNarrow_merged.csv',
#   'dailySteps_merged.csv',
#   'minuteCaloriesWide_merged.csv',
#   'minuteStepsNarrow_merged.csv',
#   'minuteStepsWide_merged.csv',
#   'weightLogInfo_merged.csv',
#   'dailyIntensities_merged.csv'])

# %%
file_names1 = os.listdir("../data2/fitbit_EDA/Fitabase Data 3.12.16-4.11.16")
file_names2 = os.listdir("../data2/fitbit_EDA/Fitabase Data 4.12.16-5.12.16")

file_names = file_names1 + file_names2

# with_threading = False
# if with_threading:
#     dirname = "data2/fitbit_EDA"
#     file_name =
#     with ThreadPoolExecutor as executor: # use a with clause to close up any worker threads running at the end of the operations
#         tqdm(executor.map(lambda func : process_csv(dirname, file_name)))

dirname = "../data2/fitbit_EDA/Fitabase Data 3.12.16-4.11.16/"
for file_name in file_names1:
    filepath = os.path.join(dirname, file_name)
    df = pd.read_csv(filepath)
    print(file_name)
    df.describe()
    print(df)
    print("--------------")
    print()
# Out:
# dailyActivity_merged.csv
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
# ...

# %% [markdown]
# ### View the average HRV per day of each one member over the duration of the study
